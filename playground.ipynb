# %%
import requests #to make HTTP URL requests
import urllib.request 
import time #to get the time.sleep function 
from bs4 import BeautifulSoup #to extract data from html files
import shelve #to save data to a shelve (kinda like matlab save workspace)
import logging #to do logging info and debug statements 
import re #regular expressions
import json
import os.path
import traceback

def loggingConfig():
    format = "%(asctime)s: %(message)s"
    logging.basicConfig(format=format, level=logging.DEBUG,
                        datefmt="%H:%M:%S")

loggingConfig()

shelveFile = "shelve.out"
try: 
    logging.debug("try to open existing shelve")
    if not os.path.exists(shelveFile + ".dat"):
        raise Exception

    my_shelf = shelve.open(shelveFile)
    logging.debug("Shelve opened")
    try:
        for key in my_shelf:
            globals()[key]=my_shelf[key]
            print(str(key))
    except:
        logging.debug("Failed during extracting shelve key")
        pass
    my_shelf.close()
    logging.debug("Shelve closed again")
    print("*** Pulled from shelve ***")

# if it doesn't exist, create the data object again
except Exception:
    traceback.print_exc()
    print("*** Pulling data from URL *** ")
    url = "https://cubavodka.com/cocktails"
    # Needed to add a different user agent, since default python one seems blocked?
    # https://stackoverflow.com/questions/56101612/python-requests-http-response-406
    response = requests.get(url, headers={"User-Agent": "XY"})
    # print(response)
    soup = BeautifulSoup(response.text, "html.parser", from_encoding='utf8')

    my_shelf = shelve.open(shelveFile,'n') # 'n' for new
    saveList = [soup]

    for key in saveList:
        try:
            my_shelf[key] = globals()[key]
        except:
            print('ERROR shelving: {0}'.format(key))
    my_shelf.close()

# Prepare an empty dictionary for all the recipies
recipeDict = {}

# Find all the different cocktails in the dataset
for tag in soup.body.find_all(class_=re.compile("cocktail-item")):
    # print(str(tag) + "\n")
    drinkImgUrl = tag["data-largeimg"]
    drinkName = tag.find("h3", attrs={"itemprop": True}).string
    recipe = tag.find(class_=re.compile("ingredients-wrap"))
    # print(recipe)

    # Put the drink into the recipeDict! 
    recipeDict[str(drinkName)] = {"ingredients": {}}

    for ingredient in recipe.find_all("li", attrs={"itemprop": True}):
        # print(ingredient)

        # Ingredients with an amount 
        try:
            ingredientName = ingredient.contents[1]
            # print(ingredientName)
            amount = ingredient.span.string
            # print(amount)
        except IndexError:
            pass

        # Ingredientwithout an amount
        try:
            if not ingredient.string == None:
                ingredientName = ingredient.string
                # print(ingredientName)
                amount = " "
        except IndexError:
            pass


        # Put it all into the dict! 
        recipeDict[str(drinkName)]["ingredients"][ingredientName] = amount


print(json.dumps(recipeDict, indent=4, sort_keys=True))

# print(recipeDict.split("}},"))
# Out:
# 11:28:04: try to open existing shelve
# 11:28:04: Shelve opened
# 11:28:04: Shelve closed again
# *** Pulled from shelve ***
# {
#     "10 stk. Lyser\u00f8de Elefanter": {
#         "ingredients": {
#             "CUBA Strawberry": "4 cl. ",
#             "Fl\u00f8deskum": "4 tsk. ",
#             "Jordb\u00e6rsirup": "2 cl. ",
#             "R\u00f8d sodavand": " "
#         }
#     },
#     "10 stk. Strawberry Smoothie shots": {
#         "ingredients": {
#             "CUBA Strawberry": "6 cl. ",
#             "Grenadine": "4 cl. ",
#             "M\u00e6lk": "10 cl. "
#         }
#     },
#     "3 farvet is": {
#         "ingredients": {
#             "CUBA Strawberry": "2 cl. ",
#             "Cocio Chokoladem\u00e6lk": "10 cl. ",
#             "Dooley's Original Toffee & Vodka": "2 cl. ",
#             "Grenadine": "2 cl. "
#         }
#     },
#     "After 8": {
#         "ingredients": {
#             "CUBA Cool Mint": "2 cl. ",
#             "Cocio Chokoladem\u00e6lk": " "
#         }
#     },
#     "Aloha": {
#         "ingredients": {
#             "CUBA Pineapple": "2 cl. ",
#             "Lime": "1/2 ",
#             "Traneb\u00e6rjuice": " "
#         }
#     },
#     "Ananas Split": {
#         "ingredients": {
#             "CUBA Pineapple": "2 cl. ",
#             "Cola": " ",
#             "Lime": " "
#         }
#     },
#     "Apple Pie": {
#         "ingredients": {
#             "CUBA Caramel": "4 cl. ",
#             "\u00c6blejuice": "8 cl. "
#         }
#     },
#     "Apricot Spritz": {
#         "ingredients": {
#             "CUBA Apricot": "2 cl. ",
#             "Mousserende Vin": " "
#         }
#     },
#     "Astronaut": {
#         "ingredients": {
#             "CUBA Dry Lemon": "2 cl. ",
#             "Hyldeblomst sodavand": " ",
#             "Solb\u00e6rsirup": " "
#         }
#     },
#     "Bahama Mama": {
#         "ingredients": {
#             "CUBA Pineapple": "2 cl. ",
#             "Sprite": " "
#         }
#     },
#     "Benzin": {
#         "ingredients": {
#             "CUBA Apricot": "4 cl. "
#         }
#     },
#     "Bitch": {
#         "ingredients": {
#             "CUBA Apricot": "2 cl. ",
#             "Sprite": " ",
#             "\u00c6blejuice": " "
#         }
#     },
#     "Black Out": {
#         "ingredients": {
#             "CUBA Dry Lemon": "2 cl. ",
#             "Cola": " "
#         }
#     },
#     "Blue Hawaii": {
#         "ingredients": {
#             "Ananasjuice": "3 cl. ",
#             "Bl\u00e5b\u00e6r": "12 stk. ",
#             "CUBA Blueberry": "2 cl. ",
#             "Vanilledessertcreme": "6 cl. "
#         }
#     },
#     "Blue Tonic": {
#         "ingredients": {
#             "CUBA Blueberry": "2 cl. ",
#             "Tonic": " "
#         }
#     },
#     "Blueberry Frozen Mojito": {
#         "ingredients": {
#             "CUBA Blueberry": "4 cl. ",
#             "Danskvand": " ",
#             "Limeb\u00e5d": "5 stk. ",
#             "Mynteblade": "4-5 stk. ",
#             "R\u00f8rsukker": "1 tsk. "
#         }
#     },
#     "Blueberry Smoothie": {
#         "ingredients": {
#             "CUBA Blueberry": "2 cl. ",
#             "Fl\u00f8de": "10 cl. ",
#             "S\u00f8dm\u00e6lk": "10 cl. "
#         }
#     },
#     "Bonita": {
#         "ingredients": {
#             "Ananasjuice": "4 cl. ",
#             "CUBA Pineapple": "2 cl. ",
#             "Sprite": " "
#         }
#     },
#     "Bounty Bay": {
#         "ingredients": {
#             "Appelsinjuice": "6 cl. ",
#             "CUBA Caramel": "2 cl. ",
#             "Fl\u00f8deskum": "2 tsk. ",
#             "Sprite": "4 cl. "
#         }
#     },
#     "Brazilian": {
#         "ingredients": {
#             "Appelsinjuice": " ",
#             "CUBA Pineapple": "2 cl. "
#         }
#     },
#     "CUBA Bite Shot": {
#         "ingredients": {
#             "CUBA Strawberry": "2 cl. ",
#             "Limeb\u00e5d": "1 stk. ",
#             "Sukker": "1 tsk. "
#         }
#     },
#     "CUBA Colada": {
#         "ingredients": {
#             "Ananasjuice": "10 cl. ",
#             "CUBA Caramel": "2 cl. "
#         }
#     },
#     "CUBA Dumle": {
#         "ingredients": {
#             "CUBA Caramel": "2 cl. ",
#             "Cocio chokoladem\u00e6lk": " "
#         }
#     },
#     "CUBA Fantastic": {
#         "ingredients": {
#             "Appelsinvand": " ",
#             "CUBA Caramel": "2 cl. ",
#             "Friskpresset citronsaft": "2 cl. "
#         }
#     },
#     "CUBA Hot Shot": {
#         "ingredients": {
#             "CUBA Caramel": "2 cl. ",
#             "Fl\u00f8deskum": "1 tsk. ",
#             "Kaffe": "2 cl. "
#         }
#     },
#     "CUBA Latte": {
#         "ingredients": {
#             "CUBA Caramel": "4 cl. ",
#             "Fl\u00f8deskum": "2 tsk. ",
#             "Kaffe": "8 cl. "
#         }
#     },
#     "CUBA Milky Way Raspberry & Liqourice": {
#         "ingredients": {
#             "CUBA Raspberry": "2 cl. ",
#             "Dooley's White Chocolate": "2 cl. ",
#             "Sismofytter Lakrids Shot": "1 cl. ",
#             "S\u00f8dm\u00e6lk": "5 cl. "
#         }
#     },
#     "CUBA Orange Azul": {
#         "ingredients": {
#             "Appelsinvand": " ",
#             "CUBA Orange": "2 cl. ",
#             "Friskpresset limesaft": "2 cl. "
#         }
#     },
#     "CUBA Rock": {
#         "ingredients": {
#             "CUBA Caramel": "4 cl. "
#         }
#     },
#     "Calippo": {
#         "ingredients": {
#             "CUBA Caramel": "2 cl. ",
#             "CUBA Pineapple": "2 cl. ",
#             "Sprite": " "
#         }
#     },
#     "Calippo Fruit": {
#         "ingredients": {
#             "Appelsinvand": " ",
#             "CUBA Passion": "2 cl. ",
#             "Grenadine": "1 cl. ",
#             "Passionsfrugt": "1/2 stk. "
#         }
#     },
#     "Caramelatt\u00e9": {
#         "ingredients": {
#             "CUBA Caramel": "2 cl. ",
#             "Fl\u00f8deskum": "3 tsk. ",
#             "Kaffe": " ",
#             "S\u00f8dm\u00e6lk": "4 cl. "
#         }
#     },
#     "Caribbean Breeze": {
#         "ingredients": {
#             "CUBA Caramel": "4 cl. ",
#             "Friskpresset limesaft": "2 cl. ",
#             "Sprite": " "
#         }
#     },
#     "Caught In The Act": {
#         "ingredients": {
#             "CUBA Strawberry": "2 cl. ",
#             "Lemon sodavand": " "
#         }
#     },
#     "ChampusBrus": {
#         "ingredients": {
#             "CUBA Caramel": "2 cl. ",
#             "Friskpresset limesaft": "1 cl. ",
#             "Gr\u00f8n Sodavand": " "
#         }
#     },
#     "Clear Passion": {
#         "ingredients": {
#             "CUBA Passion": "2 cl. ",
#             "Friskpresset citronsaft": "2 cl. ",
#             "Sprite": " "
#         }
#     },
#     "Completely For Girls": {
#         "ingredients": {
#             "CUBA Apricot": "2 cl. ",
#             "CUBA Strawberry": "2 cl. ",
#             "R\u00f8d sodavand": " "
#         }
#     },
#     "Cool Rain": {
#         "ingredients": {
#             "CUBA Cool Mint": "2 cl. ",
#             "Sprite": " "
#         }
#     },
#     "Creamy Passion Solero": {
#         "ingredients": {
#             "Appelsinjuice": " ",
#             "CUBA Passion": "2 cl. ",
#             "Fl\u00f8de": "2 cl. "
#         }
#     },
#     "Crispy Caramel": {
#         "ingredients": {
#             "CUBA Caramel": "2 cl. ",
#             "Sprite": "4 cl. ",
#             "\u00c6blejuice": "4 cl. "
#         }
#     },
#     "Cubanasplit": {
#         "ingredients": {
#             "Bananlik\u00f8r": "1 cl. ",
#             "CUBA Caramel": "2 cl. ",
#             "M\u00e6lk": "6 cl. "
#         }
#     },
#     "Cubatini": {
#         "ingredients": {
#             "CUBA Caramel": "4 cl. ",
#             "CUBA Pure Vodka": "2 cl. "
#         }
#     },
#     "Deep Blue Sea": {
#         "ingredients": {
#             "Ananasjuice": " ",
#             "CUBA Blueberry": "2 cl. ",
#             "CUBA Orange": "2 cl. "
#         }
#     },
#     "Dry Tom Collins": {
#         "ingredients": {
#             "CUBA Dry Lemon": "2 cl. ",
#             "Friskpresset citronsaft": " ",
#             "Lemon sodavand": " "
#         }
#     },
#     "Eagle": {
#         "ingredients": {
#             "Ananasjuice": " ",
#             "CUBA Strawberry": "2 cl. ",
#             "Friskpresset citronsaft": "2 cl. "
#         }
#     },
#     "Energizer": {
#         "ingredients": {
#             "CUBA Caramel": "2 cl. ",
#             "Energidrik": " "
#         }
#     },
#     "Epo": {
#         "ingredients": {
#             "CUBA Caramel": "2 cl. ",
#             "Whiskey": "2 cl. "
#         }
#     },
#     "Exotic Colada": {
#         "ingredients": {
#             "Ananasjuice": " ",
#             "CUBA Mango": "2 cl. ",
#             "CUBA Pineapple": "2 cl. ",
#             "Fl\u00f8de": "2 cl. "
#         }
#     },
#     "Filur": {
#         "ingredients": {
#             "Appelsinjuice": "8 cl. ",
#             "CUBA Apricot": "2 cl. ",
#             "R\u00f8d sodavand": "4 cl. "
#         }
#     },
#     "Fluffy": {
#         "ingredients": {
#             "CUBA Mango": "2 cl. ",
#             "Hyldeblomst sorbet": "2 scoop ",
#             "Tonic": " "
#         }
#     },
#     "Fluffy Fruit Salad": {
#         "ingredients": {
#             "Ananasjuice": "6 cl. ",
#             "CUBA Apricot": "2 cl. ",
#             "Fl\u00f8de": "1 cl. ",
#             "R\u00f8d sodavand": " "
#         }
#     },
#     "Freak Out": {
#         "ingredients": {
#             "CUBA Apricot": " ",
#             "CUBA Caramel": "2 cl. ",
#             "Lemon sodavand": " "
#         }
#     },
#     "Fresh Bite": {
#         "ingredients": {
#             "CUBA Strawberry": "2 cl. ",
#             "Sprite": "4 cl. ",
#             "\u00c6blejuice": "4 cl. "
#         }
#     },
#     "Frosty Pineapple": {
#         "ingredients": {
#             "Ananasjuice": "3 cl. ",
#             "CUBA Cool Mint": "1 cl. ",
#             "CUBA Pineapple": "3 cl. ",
#             "Danskvand": " "
#         }
#     },
#     "Ginger Splice": {
#         "ingredients": {
#             "CUBA Caramel": "2 cl. ",
#             "Ginger ale": " "
#         }
#     },
#     "Golden Summer": {
#         "ingredients": {
#             "Appelsinjuice": " ",
#             "CUBA Apricot": "2 cl. ",
#             "CUBA Strawberry": "2 cl. ",
#             "Fl\u00f8de": " ",
#             "Pur\u00e9 af jordb\u00e6r": "3 tsk. "
#         }
#     },
#     "Green Lagoon": {
#         "ingredients": {
#             "CUBA Watermelon": "2 cl. ",
#             "Gr\u00f8n Sodavand": " "
#         }
#     },
#     "Haiti": {
#         "ingredients": {
#             "Ananasjuice": "10 cl. ",
#             "CUBA Strawberry": "2 cl. ",
#             "Fl\u00f8deskum": "2 tsk. ",
#             "Jordb\u00e6r": "1-2 stk. "
#         }
#     },
#     "Hanky Panky": {
#         "ingredients": {
#             "Ananasjuice": "2 cl. ",
#             "CUBA Blueberry": "2 cl. "
#         }
#     },
#     "Hawaii Lover": {
#         "ingredients": {
#             "CUBA Pineapple": "2 cl. ",
#             "Cola": " "
#         }
#     },
#     "Heaven": {
#         "ingredients": {
#             "CUBA Mango": "2 cl. ",
#             "Friskpresset citronsaft": " ",
#             "Tonic": "8 cl. "
#         }
#     },
#     "Hindb\u00e6r L\u00e6ske": {
#         "ingredients": {
#             "CUBA Raspberry": "2 cl. ",
#             "Friskpresset limesaft": "1 cl. ",
#             "Gr\u00f8n sodavand": " "
#         }
#     },
#     "Hippie": {
#         "ingredients": {
#             "CUBA Blueberry": "2 cl. ",
#             "Sprite": " "
#         }
#     },
#     "Honolulu": {
#         "ingredients": {
#             "CUBA Pineapple": "2 cl. ",
#             "CUBA Watermelon": "2 cl. ",
#             "Sprite": " "
#         }
#     },
#     "Hubbabubba": {
#         "ingredients": {
#             "CUBA Blueberry": "2 cl. ",
#             "Grenadine": "1 cl. ",
#             "Lemon sodavand": " "
#         }
#     },
#     "Ice Shot": {
#         "ingredients": {
#             "CUBA Cool Mint": "2 cl. "
#         }
#     },
#     "Isbj\u00f8rn": {
#         "ingredients": {
#             "CUBA Orange": "2 cl. ",
#             "Sprite": " "
#         }
#     },
#     "Jelly Baby": {
#         "ingredients": {
#             "CUBA Caramel": "4 cl. ",
#             "Lemon sodavand": " "
#         }
#     },
#     "Jordb\u00e6r H\u00f8st": {
#         "ingredients": {
#             "CUBA Strawberry": "2 cl. ",
#             "Fl\u00f8de": "1 dl. ",
#             "Grenadine": "2 cl. ",
#             "Kokoslik\u00f8r": "4 cl. ",
#             "Sprite": " "
#         }
#     },
#     "Juicy Pineapple": {
#         "ingredients": {
#             "CUBA Pineapple": "2 cl. ",
#             "Danskvand": " ",
#             "Friskpresset limesaft": "1 cl. "
#         }
#     },
#     "Just Peachy": {
#         "ingredients": {
#             "CUBA Caramel": "4 cl. ",
#             "Ice Tea Peach": "12 cl. ",
#             "Sprite": "4 cl. "
#         }
#     },
#     "Kafforange": {
#         "ingredients": {
#             "CUBA Orange": "2 cl. ",
#             "Kaffe": " ",
#             "M\u00f8rk Chokolade": "1 stk. "
#         }
#     },
#     "Kick Off": {
#         "ingredients": {
#             "CUBA Apricot": "2 cl. ",
#             "CUBA Caramel": "2 cl. ",
#             "Sprite": " "
#         }
#     },
#     "Kongen af Danmark": {
#         "ingredients": {
#             "CUBA Cool Mint": "2 cl. ",
#             "R\u00f8d sodavand": " "
#         }
#     },
#     "K\u00e6mpe Eskimo": {
#         "ingredients": {
#             "CUBA Caramel": "2 cl. ",
#             "Solb\u00e6rsirup": " ",
#             "Vaniljeis": " "
#         }
#     },
#     "K\u00e6mpe L\u00e6ske": {
#         "ingredients": {
#             "CUBA Dry Lemon": "2 cl. ",
#             "Friskpresset limesaft": " ",
#             "Sprite": " "
#         }
#     },
#     "K\u00f8benhavnerstang": {
#         "ingredients": {
#             "Appelsinjuice": " ",
#             "CUBA Pineapple": "2 cl. ",
#             "Fl\u00f8deskum": " "
#         }
#     },
#     "La Luna": {
#         "ingredients": {
#             "CUBA Caramel": "2 cl. ",
#             "CUBA Orange": "2 cl. ",
#             "Sprite": " "
#         }
#     },
#     "Laber Larve": {
#         "ingredients": {
#             "Abrikossirup": "1 cl. ",
#             "CUBA Caramel": "2 cl. ",
#             "Cola": " "
#         }
#     },
#     "Lemon Drop": {
#         "ingredients": {
#             "CUBA Dry Lemon": "2 cl. ",
#             "Friskpresset citronsaft": "2 cl. ",
#             "Hyldeblomstsaft": "8 cl. "
#         }
#     },
#     "Lemon Style": {
#         "ingredients": {
#             "CUBA Apricot": "2 cl. ",
#             "Lemon sodavand": " "
#         }
#     },
#     "Love Spray": {
#         "ingredients": {
#             "CUBA Pure Vodka": "2 cl. ",
#             "Friskpresset limesaft": "1 stk. ",
#             "R\u00f8d sodavand": " "
#         }
#     },
#     "Malaga": {
#         "ingredients": {
#             "CUBA Mango": "2 cl. ",
#             "Friskpresset limesaft": "2 cl. ",
#             "Pink grape sodavand": "8 cl. "
#         }
#     },
#     "Mama Mia": {
#         "ingredients": {
#             "CUBA Pineapple": "2 cl. ",
#             "Lemon sodavand": " "
#         }
#     },
#     "Mambo": {
#         "ingredients": {
#             "CUBA Strawberry": "2 cl. ",
#             "Friskpresset citronsaft": "2 cl. ",
#             "Grenadine": "1 cl. ",
#             "Tonic": "6 cl. "
#         }
#     },
#     "Mango Colada": {
#         "ingredients": {
#             "Ananasjuice": "8 cl. ",
#             "CUBA Mango": "2 cl. ",
#             "Fl\u00f8de": "2 cl. "
#         }
#     },
#     "Mango Hazz": {
#         "ingredients": {
#             "CUBA Mango": "2 cl. ",
#             "Friskpresset limesaft": " ",
#             "Lemon sodavand": " "
#         }
#     },
#     "Mango Mania": {
#         "ingredients": {
#             "CUBA Mango": "2 cl. ",
#             "Friskpresset limesaft": "2 cl. ",
#             "Sprite": " "
#         }
#     },
#     "Mango Sunrise": {
#         "ingredients": {
#             "Appelsinvand": " ",
#             "CUBA Mango": "2 cl. ",
#             "Friskpresset citronsaft": "2 cl. ",
#             "Solb\u00e6rsirup": "1 cl. "
#         }
#     },
#     "Mango grape": {
#         "ingredients": {
#             "CUBA Mango": "2 cl. ",
#             "Grape sodavand": " "
#         }
#     },
#     "Matador": {
#         "ingredients": {
#             "Appelsinvand": "6 cl. ",
#             "CUBA Caramel": "2 cl. ",
#             "Cola": " "
#         }
#     },
#     "Melon Must": {
#         "ingredients": {
#             "CUBA Watermelon": "2 cl. ",
#             "Lemon sodavand": " "
#         }
#     },
#     "Melon Water": {
#         "ingredients": {
#             "CUBA Watermelon": "2 cl. ",
#             "Sprite": " "
#         }
#     },
#     "Melon dream": {
#         "ingredients": {
#             "Ananasjuice": " ",
#             "CUBA Watermelon": "2 cl. ",
#             "Fl\u00f8deskum": " "
#         }
#     },
#     "Midnight Melon": {
#         "ingredients": {
#             "CUBA Watermelon": "2 cl. ",
#             "Traneb\u00e6rjuice": " "
#         }
#     },
#     "Mint Must": {
#         "ingredients": {
#             "Ananasjuice": " ",
#             "CUBA Cool Mint": "2 cl. "
#         }
#     },
#     "Miss Passion": {
#         "ingredients": {
#             "CUBA Passion": "2 cl. ",
#             "Lemon sodavand": " "
#         }
#     },
#     "Moonlight": {
#         "ingredients": {
#             "CUBA Dry Lemon": "2 cl. ",
#             "Solb\u00e6rsirup": "1 cl. ",
#             "Tonic": "8 cl. "
#         }
#     },
#     "Moscow": {
#         "ingredients": {
#             "CUBA Dry Lemon": "2 cl. ",
#             "Ginger beer": "8 cl. "
#         }
#     },
#     "Moscow Mule": {
#         "ingredients": {
#             "CUBA Pure Vodka": "4 cl. ",
#             "Friskpresset limesaft": "2 cl. ",
#             "Ginger beer": "10 cl. "
#         }
#     },
#     "Must Have": {
#         "ingredients": {
#             "CUBA Mango": "2 cl. ",
#             "Ginger beer": "8 cl. ",
#             "Solb\u00e6rsirup": "1 cl. "
#         }
#     },
#     "Natural": {
#         "ingredients": {
#             "CUBA Blueberry": "2 cl. ",
#             "Danskvand": " "
#         }
#     },
#     "Naughty Bottom": {
#         "ingredients": {
#             "CUBA Passion": "2 cl. ",
#             "Ginger ale": "8 cl. ",
#             "Jordb\u00e6r": "3 stk. ",
#             "Jordb\u00e6rsirup": "1 cl. ",
#             "Limeb\u00e5d": "3 stk. "
#         }
#     },
#     "New York": {
#         "ingredients": {
#             "CUBA Dry Lemon": "2 cl. ",
#             "Friskpresset citronsaft": " ",
#             "Tonic": "8 cl. "
#         }
#     },
#     "Nice Coma": {
#         "ingredients": {
#             "CUBA Mango": "2 cl. ",
#             "Cola": " "
#         }
#     },
#     "Number 1": {
#         "ingredients": {
#             "CUBA Apricot": "2 cl. ",
#             "CUBA Passion": "2 cl. ",
#             "Grenadine": "1 cl. ",
#             "Lemon sodavand": " "
#         }
#     },
#     "Oh Ginger": {
#         "ingredients": {
#             "CUBA Orange": "2 cl. ",
#             "Ginger ale": " "
#         }
#     },
#     "Orange Fresh": {
#         "ingredients": {
#             "Appelsinvand": " ",
#             "CUBA Cool Mint": "2 cl. "
#         }
#     },
#     "Orange Knas": {
#         "ingredients": {
#             "CUBA Orange": "2 cl. ",
#             "Cocio Chokoladem\u00e6lk": " "
#         }
#     },
#     "Orange Strawberry Sky": {
#         "ingredients": {
#             "Appelsinjuice": " ",
#             "CUBA Orange": "2 cl. ",
#             "CUBA Strawberry": "2 cl. ",
#             "Grenadine": "2 cl. "
#         }
#     },
#     "Pacific Dream": {
#         "ingredients": {
#             "Appelsinvand": " ",
#             "CUBA Apricot": "2 cl. ",
#             "CUBA Strawberry": "2 cl. ",
#             "Sprite": " "
#         }
#     },
#     "Passion Float": {
#         "ingredients": {
#             "Ananasjuice": " ",
#             "CUBA Passion": "4 cl. "
#         }
#     },
#     "Passion Float Shots": {
#         "ingredients": {
#             "Ananasjuice": "6 cl. ",
#             "CUBA Passion": "10 cl. ",
#             "Fl\u00f8de": "14 cl. "
#         }
#     },
#     "Passion Mojito": {
#         "ingredients": {
#             "CUBA Passion": "2 cl. ",
#             "Danskvand": "8 cl. ",
#             "Limeb\u00e5d": "3 stk. ",
#             "Mynteblade": "4 stk. ",
#             "R\u00f8rsukker": "2 tsk. "
#         }
#     },
#     "Passion Orange": {
#         "ingredients": {
#             "Appelsinvand": " ",
#             "CUBA Passion": "2 cl. ",
#             "Limeb\u00e5d": "2 stk. ",
#             "Passionsfrugt": "1/2 stk. "
#         }
#     },
#     "Passion Sunrise": {
#         "ingredients": {
#             "Appelsinjuice": "6 cl. ",
#             "CUBA Passion": "2 cl. ",
#             "R\u00f8d sodavand": "6 cl. "
#         }
#     },
#     "Passion Twist": {
#         "ingredients": {
#             "CUBA Passion": "2 cl. ",
#             "\u00c6blemost": " "
#         }
#     },
#     "Perfect": {
#         "ingredients": {
#             "CUBA Raspberry": "2 cl. ",
#             "Lemon sodavand": " "
#         }
#     },
#     "Pineapple Refresher": {
#         "ingredients": {
#             "CUBA Apricot": "2 cl. ",
#             "CUBA Orange": "2 cl. ",
#             "Pur\u00e9 af ananas": "1-2 tsk. ",
#             "Sour mix": "1 tsk. "
#         }
#     },
#     "Piniapoppers": {
#         "ingredients": {
#             "CUBA Mango": "1 cl. ",
#             "CUBA Pineapple": "2 cl. ",
#             "Danskvand": " ",
#             "Friskpresset limesaft": "1 cl. "
#         }
#     },
#     "Pink Dry": {
#         "ingredients": {
#             "CUBA Dry Lemon": "2 cl. ",
#             "Friskpresset limesaft": " ",
#             "Granat\u00e6blesirup": "1 cl. ",
#             "Lemon sodavand": " "
#         }
#     },
#     "Pink Poetry": {
#         "ingredients": {
#             "CUBA Dry Lemon": "2 cl. ",
#             "Friskpresset citronsaft": " ",
#             "Pink grapefrugt tonic": " "
#         }
#     },
#     "Pink Pussy": {
#         "ingredients": {
#             "CUBA Raspberry": "2 cl. ",
#             "Fl\u00f8deskum": "2 spsk. ",
#             "Grenadine": "2 cl. ",
#             "Sprite": " "
#         }
#     },
#     "Pink Razzia": {
#         "ingredients": {
#             "CUBA Raspberry": "2 cl. ",
#             "Sprite": " "
#         }
#     },
#     "Pinky Coco Loco": {
#         "ingredients": {
#             "CUBA Pineapple": "2 cl. ",
#             "Grenadine": "1 cl. ",
#             "M\u00e6lk": "6 cl. "
#         }
#     },
#     "Pi\u00f1a Colada": {
#         "ingredients": {
#             "Ananasjuice": " ",
#             "CUBA Pineapple": "4 cl. ",
#             "Fl\u00f8de": "2 cl. "
#         }
#     },
#     "Pi\u00f1ango": {
#         "ingredients": {
#             "Ananasjuice": "4 cl. ",
#             "CUBA Mango": "2 cl. ",
#             "Lemon sodavand": "8 cl. "
#         }
#     },
#     "Polarbj\u00f8rn": {
#         "ingredients": {
#             "Ananasjuice": " ",
#             "CUBA Orange": "4 cl. "
#         }
#     },
#     "Power Passion": {
#         "ingredients": {
#             "CUBA Passion": "2 cl. ",
#             "Energidrik": " "
#         }
#     },
#     "Prescious": {
#         "ingredients": {
#             "CUBA Apricot": "2 cl. ",
#             "Sprite": " "
#         }
#     },
#     "Princess": {
#         "ingredients": {
#             "CUBA Caramel": "2 cl. ",
#             "Sprite": "4 cl. ",
#             "Traneb\u00e6rjuice": "8 cl. "
#         }
#     },
#     "Pulp": {
#         "ingredients": {
#             "Appelsinvand": " ",
#             "CUBA Mango": "2 cl. ",
#             "Pink grape juice": "8 cl. "
#         }
#     },
#     "Pure Citrus": {
#         "ingredients": {
#             "CUBA Pure Vodka": "2 cl. ",
#             "Friskpresset citronsaft": "2 cl. ",
#             "Sprite": " "
#         }
#     },
#     "Pure Cosmopolitan": {
#         "ingredients": {
#             "CUBA Pure Vodka": "2 cl. ",
#             "Friskpresset limesaft": "1/2 stk. ",
#             "Traneb\u00e6rjuice": " "
#         }
#     },
#     "Pure Energy": {
#         "ingredients": {
#             "CUBA Pure Vodka": "2 cl. ",
#             "Energidrik": " "
#         }
#     },
#     "Pure\u2019n\u2019Coke": {
#         "ingredients": {
#             "CUBA Pure Vodka": "2 cl. ",
#             "Cola": " ",
#             "Friskpresset citronsaft": "2 cl. "
#         }
#     },
#     "Purple Rain": {
#         "ingredients": {
#             "Bl\u00e5b\u00e6r": "2-3 stk. ",
#             "CUBA Blueberry": "2 cl. ",
#             "Citron": "1 skive ",
#             "Lemon sodavand": "6 cl. ",
#             "R\u00f8d sodavand": "4 cl. "
#         }
#     },
#     "Purple Sky": {
#         "ingredients": {
#             "Bl\u00e5b\u00e6r": "4-5 stk. ",
#             "CUBA Blueberry": "2 cl. ",
#             "Citron": "1-2 skiver ",
#             "Cola": " "
#         }
#     },
#     "Rainforest": {
#         "ingredients": {
#             "Appelsinvand": " ",
#             "CUBA Watermelon": "3 cl. "
#         }
#     },
#     "Raspberry Spritzer": {
#         "ingredients": {
#             "CUBA Raspberry": "2 cl. ",
#             "Mousserende vin": " "
#         }
#     },
#     "Red love": {
#         "ingredients": {
#             "CUBA Pineapple": "2 cl. ",
#             "R\u00f8d sodavand": " "
#         }
#     },
#     "Rhubarb Sour": {
#         "ingredients": {
#             "CUBA Dry Lemon": "2 cl. ",
#             "Danskvand": " ",
#             "Rabarbersaft": " "
#         }
#     },
#     "Samba": {
#         "ingredients": {
#             "CUBA Pineapple": "2 cl. ",
#             "Gr\u00f8n Sodavand": " "
#         }
#     },
#     "Sex In The Field": {
#         "ingredients": {
#             "CUBA Strawberry": "2 cl. ",
#             "\u00c6blejuice": " "
#         }
#     },
#     "Side Kick": {
#         "ingredients": {
#             "CUBA Orange": "2 cl. ",
#             "Cola": " "
#         }
#     },
#     "Simple": {
#         "ingredients": {
#             "Ananasjuice": " ",
#             "CUBA Raspberry": "2 cl. "
#         }
#     },
#     "Skinny Dipping": {
#         "ingredients": {
#             "CUBA Caramel": "2 cl. ",
#             "CUBA Orange": "2 cl. "
#         }
#     },
#     "Skumbanan": {
#         "ingredients": {
#             "Bananlik\u00f8r": "2 cl. ",
#             "CUBA Caramel": "2 cl. ",
#             "Cocio Chokoladem\u00e6lk": "2 cl. "
#         }
#     },
#     "Sky High": {
#         "ingredients": {
#             "Appelsin": "1-2 skiver ",
#             "Appelsinvand": " ",
#             "CUBA Dry Lemon": "2 cl. "
#         }
#     },
#     "Solero": {
#         "ingredients": {
#             "Appelsinjuice": "6 cl. ",
#             "CUBA Strawberry": "2 cl. ",
#             "Fl\u00f8deskum": "2 tsk. ",
#             "Sprite": "4 cl. "
#         }
#     },
#     "Solero Exotic": {
#         "ingredients": {
#             "CUBA Mango": "2 cl. ",
#             "Fl\u00f8deskum": " ",
#             "Friskpresset limesaft": " ",
#             "Sprite": " "
#         }
#     },
#     "Solstang": {
#         "ingredients": {
#             "CUBA Strawberry": "2 cl. ",
#             "Friskpresset limesaft": " ",
#             "Grenadine": " ",
#             "Lemon sodavand": " "
#         }
#     },
#     "Sommerstang": {
#         "ingredients": {
#             "CUBA Caramel": "2 cl. ",
#             "Cola": " ",
#             "Friskpresset citronsaft": "2 cl. "
#         }
#     },
#     "Speed Up": {
#         "ingredients": {
#             "CUBA Strawberry": "2 cl. ",
#             "Red Bull": " "
#         }
#     },
#     "Spicy Hurricane": {
#         "ingredients": {
#             "Ananasjuice": "3 cl. ",
#             "CUBA Passion": "2 cl. ",
#             "Rom": "2 cl. "
#         }
#     },
#     "Spray": {
#         "ingredients": {
#             "CUBA Apricot": "2 cl. ",
#             "Friskpresset citronsaft": "2 cl. ",
#             "Sprite": " "
#         }
#     },
#     "Spring-buk": {
#         "ingredients": {
#             "CUBA Cool Mint": "1 cl. ",
#             "Dooley's Original Toffee & Vodka": "1 cl. "
#         }
#     },
#     "Strawberry Daquiri": {
#         "ingredients": {
#             "CUBA Strawberry": "2 cl. ",
#             "Golden Pirate Rum": "2 cl. ",
#             "Pur\u00e9 af jordb\u00e6r": "3 tsk. ",
#             "Sour mix": "1-2 cl. "
#         }
#     },
#     "Strawberry Dreams": {
#         "ingredients": {
#             "CUBA Strawberry": "2 cl. ",
#             "Grenadine": "2 cl. ",
#             "Lemon sodavand": " "
#         }
#     },
#     "Strawberry Kiss": {
#         "ingredients": {
#             "Ananasjuice": "3 cl. ",
#             "CUBA Strawberry": "3 cl. ",
#             "Hyldeblomstsaft": "10 cl. "
#         }
#     },
#     "Strawberry Mojito": {
#         "ingredients": {
#             "CUBA Strawberry": "2 cl. ",
#             "Danskvand": " ",
#             "Limeb\u00e5d": "5 stk. ",
#             "Mynteblade": "3-4 stk. ",
#             "R\u00f8rsukker": "1 tsk. "
#         }
#     },
#     "Strawberry Paradise": {
#         "ingredients": {
#             "CUBA Strawberry": "2 cl. ",
#             "Fl\u00f8deskum": "2 tsk. ",
#             "Grenadine": "1 cl. ",
#             "Sprite": " "
#         }
#     },
#     "Summer Love": {
#         "ingredients": {
#             "CUBA Dry Lemon": "2 cl. ",
#             "Sprite": " "
#         }
#     },
#     "Summer Sunrise": {
#         "ingredients": {
#             "CUBA Apricot": "2 cl. ",
#             "R\u00f8d sodavand": " "
#         }
#     },
#     "Sun Down": {
#         "ingredients": {
#             "Ananasjuice": " ",
#             "Appelsinjuice": " ",
#             "CUBA Apricot": "2 cl. "
#         }
#     },
#     "Sun Kiss": {
#         "ingredients": {
#             "Appelsin": "1-2 skiver ",
#             "Appelsinvand": " ",
#             "CUBA Raspberry": "2 cl. ",
#             "Hindb\u00e6r": "2-3 stk. "
#         }
#     },
#     "Sweet Apple": {
#         "ingredients": {
#             "CUBA Pure Vodka": "2 cl. ",
#             "Sprite": "4 cl. ",
#             "\u00c6blejuice": "4 cl. "
#         }
#     },
#     "Sweet Lime and Sour": {
#         "ingredients": {
#             "CUBA Dry Lemon": "2 cl. ",
#             "Friskpresset citronsaft": " ",
#             "Sour mix": "2 cl. "
#         }
#     },
#     "Sweet Tea": {
#         "ingredients": {
#             "CUBA Apricot": "4 cl. ",
#             "Ice tea peach": " "
#         }
#     },
#     "Tango Orango": {
#         "ingredients": {
#             "Appelsinjuice": "6 cl. ",
#             "CUBA Caramel": "2 cl. ",
#             "Fl\u00f8deskum": "1-2 tsk. ",
#             "Sprite": " "
#         }
#     },
#     "The Green House": {
#         "ingredients": {
#             "CUBA Dry Lemon": "2 cl. ",
#             "Ufiltreret \u00e6blemost": "10 cl. "
#         }
#     },
#     "The Twin Sister": {
#         "ingredients": {
#             "CUBA Dry Lemon": "2 cl. ",
#             "Lemon sodavand": " "
#         }
#     },
#     "Tiger": {
#         "ingredients": {
#             "Appelsinjuice": "6 cl. ",
#             "CUBA Caramel": "2 cl. ",
#             "Sprite": "4 cl. "
#         }
#     },
#     "Too Easy": {
#         "ingredients": {
#             "CUBA Cool Mint": "2 cl. ",
#             "Lemon sodavand": " "
#         }
#     },
#     "Tropic": {
#         "ingredients": {
#             "Ananasjuice": " ",
#             "CUBA Watermelon": "2 cl. ",
#             "Friskpresset limesaft": "1 cl. "
#         }
#     },
#     "Tropic Passion": {
#         "ingredients": {
#             "Abrikos Sodavand": " ",
#             "CUBA Passion": "2 cl. "
#         }
#     },
#     "Twisted": {
#         "ingredients": {
#             "CUBA Blueberry": "2 cl. ",
#             "Lemon sodavand": " "
#         }
#     },
#     "Twisted Sister": {
#         "ingredients": {
#             "Appelsinvand": " ",
#             "CUBA Strawberry": "2 cl. "
#         }
#     },
#     "Twister": {
#         "ingredients": {
#             "CUBA Pineapple": "2 cl. ",
#             "CUBA Strawberry": "2 cl. ",
#             "Lemon sodavand": " "
#         }
#     },
#     "Uh la la la la\u2026.": {
#         "ingredients": {
#             "CUBA Strawberry": "2 cl. ",
#             "Friskpresset limesaft": "1 cl. ",
#             "Sprite": " "
#         }
#     },
#     "Ultimate Strawberry Dreams": {
#         "ingredients": {
#             "CUBA Strawberry": "2 cl. ",
#             "Grenadine": "1 cl. ",
#             "Lemon sodavand": " "
#         }
#     },
#     "Vanilla Heaven": {
#         "ingredients": {
#             "Ananasjuice": "2 cl. ",
#             "CUBA Strawberry": "2 cl. ",
#             "Jordb\u00e6r": "4-5 stk. ",
#             "Jordb\u00e6rsirup": "2 cl. ",
#             "Vanilledessertcreme": "6 cl. "
#         }
#     },
#     "Vingummi": {
#         "ingredients": {
#             "CUBA Apricot": " ",
#             "Citronvand": " "
#         }
#     },
#     "Viper": {
#         "ingredients": {
#             "CUBA Orange": "2 cl. ",
#             "Lemon sodavand": " "
#         }
#     },
#     "Viva la Vida": {
#         "ingredients": {
#             "CUBA Strawberry": "2 cl. ",
#             "Kokoslik\u00f8r": "2 cl. ",
#             "Sprite": " "
#         }
#     },
#     "Vodka Bramble": {
#         "ingredients": {
#             "Bromb\u00e6rsirup": " ",
#             "CUBA Dry Lemon": "2 cl. ",
#             "Danskvand": " "
#         }
#     },
#     "Winner": {
#         "ingredients": {
#             "CUBA Caramel": "6 cl. ",
#             "Traneb\u00e6rjuice": "12 cl. "
#         }
#     },
#     "Wofler": {
#         "ingredients": {
#             "Ananasjuice": " ",
#             "CUBA Caramel": "2 cl. ",
#             "CUBA Pineapple": "2 cl. ",
#             "Fl\u00f8de": "2 cl. "
#         }
#     },
#     "Yellow daydream": {
#         "ingredients": {
#             "Appelsinvand": " ",
#             "CUBA Mango": "2 cl. ",
#             "Friskpresset limesaft": " "
#         }
#     },
#     "Zumba": {
#         "ingredients": {
#             "CUBA Orange": "2 cl. ",
#             "CUBA Pineapple": "2 cl. ",
#             "Lemon sodavand": " "
#         }
#     },
#     "\u00c6vle B\u00e6vle": {
#         "ingredients": {
#             "CUBA Pure Vodka": "2 cl. ",
#             "\u00c6blejuice": " "
#         }
#     },
#     "\u201cThe Milky Way\u201d": {
#         "ingredients": {
#             "CUBA Caramel": "4 cl. ",
#             "M\u00e6lk": "12 cl. "
#         }
#     }
# }
